# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %% [markdown]
# **Criando uma String**

# %% [markdown]
# Para criar uma string em Python você pode usar aspas simples ou dulpas. Por exemplo:

# %%
# Uma única palavra
'Oi'
# Out:
# 'Oi'

# %%
# Uma frase
'Criando uma string em Python'
# Out:
# 'Criando uma string em Python'

# %%
# Podemos usar aspas duplas
"Podemos usar aspas duplas ou simples para strings em Python"
# Out:
# 'Podemos usar aspas duplas ou simples para strings em Python'

# %%
# Você pode combinar aspas duplas e simples
"Testando String em 'Python'"
# Out:
# "Testando String em 'Python'"

# %% [markdown]
# **Imprimindo uma String**

# %%
print ('Testando Strings em Python')
# Out:
# Testando Strings em Python

# %%
print ('Testando \nStrings \nem \nPython')
# Out:
# Testando
# Strings
# em
# Python

# %%
print ('\n')

# %% [markdown]
# **Indexando String**

# %%
# Atribuindo uma string
s = 'Data Science Academy'

# %%
print(s)
# Out:
# Data Science Academy

# %% [markdown]
# Indexação em Python começar por zero.

# %%
# Primeiro elemento da string
s[0]
# Out:
# 'D'

# %%
s[1]
# Out:
# 'a'

# %%
s[2]
# Out:
# 't'

# %%
s[3]
# Out:
# 'a'

# %%
s[4]
# Out:
# ' '

# %% [markdown]
# Podemos usar um : para executar um slicing que faz leitura de tudo até um ponto designado. Por exemplo:

# %%
# Retorna todos os elementos da string, começando pela posição
# (lembre-se que Python começa a indexação pela posição 0),
# até o fim da string.
s[1:]
# Out:
# 'ata Science Academy'

# %%
# A string original permance inalterda
s
# Out:
# 'Data Science Academy'

# %%
# Retorna tudo até a posição 3
s[:3]
# Out:
# 'Dat'

# %%
# Retorna tudo até a posição 4
s[:4]
# Out:
# 'Data'

# %%
# Nós também podemos usar a indexação negativa e ler de trás para frente
s[-1]
# Out:
# 'y'

# %%
# Retornar tudo, exceto a últuma letra
s[:-1]
# Out:
# 'Data Science Academ'

# %% [markdown]
# Nós também podemos usar a notação de índice e fatiar a string em pedaços específios (o padrão é 1).

# %% [markdown]
# Por exemplo, podemos usar dois pontos duas vezes em uma linha e, em seguida, um número que especifica a frequência para retornar elemntos.

# %%
s[::1]
# Out:
# 'Data Science Academy'

# %%
s[::2]
# Out:
# 'Dt cec cdm'

# %%
s[::-1]
# Out:
# 'ymedacA ecneicS ataD'

# %% [markdown]
# **Propriedades de Strings**

# %%
s
# Out:
# 'Data Science Academy'

# %%
# Alterando um caracter (não é possível alterar um elemnto da string)
s[0 = 'x']
# Out:
#   File "C:\Users\Igor\AppData\Local\Temp\ipykernel_17192\3213879141.py", line 2
#     s[0 = 'x']
#         ^
# SyntaxError: invalid syntax

# %%
# Concatenando strings
s + ' é a melhor maneira de estar preparado para o mercado de trabalho em Ciência de Dados!'
# Out:
# 'Data Science Academy é a melhor maneira de estar preparado para o mercado de trabalho em Ciência de Dados!'

# %%
s = s + ' é a melhor maneira de estar preparado para o mercado de trabalho em Ciência de Dados!'

# %%
print(s)
# Out:
# Data Science Academy é a melhor maneira de estar preparado para o mercado de trabalho em Ciência de Dados!

# %%
# Podemos usar o símbolo de multiplicação para criar repetição!
letra = 'w'

# %%
letra * 3
# Out:
# 'www'

# %% [markdown]
# **Funções Built-in de Strings**

# %%
s
# Out:
# 'Data Science Academy é a melhor maneira de estar preparado para o mercado de trabalho em Ciência de Dados!'

# %%
# Upper case
s.upper()
# Out:
# 'DATA SCIENCE ACADEMY É A MELHOR MANEIRA DE ESTAR PREPARADO PARA O MERCADO DE TRABALHO EM CIÊNCIA DE DADOS!'

# %%
# Lower case
s.lower()
# Out:
# 'data science academy é a melhor maneira de estar preparado para o mercado de trabalho em ciência de dados!'

# %%
# Dividir uma string por espaços em branco (padrão)
s.split()
# Out:
# ['Data',
#  'Science',
#  'Academy',
#  'é',
#  'a',
#  'melhor',
#  'maneira',
#  'de',
#  'estar',
#  'preparado',
#  'para',
#  'o',
#  'mercado',
#  'de',
#  'trabalho',
#  'em',
#  'Ciência',
#  'de',
#  'Dados!']

# %%
# Dividir uma string por um elemnto específico
s.split('y')
# Out:
# ['Data Science Academ',
#  ' é a melhor maneira de estar preparado para o mercado de trabalho em Ciência de Dados!']

# %% [markdown]
# **Funçoes String**

# %%
s = 'seja bem vindo ao univero da Linguagem Python!'

# %%
s
# Out:
# 'seja bem vindo ao univero da Linguagem Python!'

# %%
s.capitalize()
# Out:
# 'Seja bem vindo ao univero da linguagem python!'

# %%
s.count('a')
# Out:
# 4

# %%
s.isalnum()
# Out:
# False

# %%
s.islower()
# Out:
# False

# %%
s.isspace()
# Out:
# False

# %%
s.endswith('o')
# Out:
# False

# %%
s = '1000'

# %% [markdown]
# **Comparando Strings**
