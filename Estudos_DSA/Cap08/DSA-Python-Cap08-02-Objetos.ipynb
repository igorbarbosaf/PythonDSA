# %%
# Versão da Linguegem Python
from platform import python_version
print('Versão da Linguegem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguegem Python Usada Neste Jupyter Notebook: 3.10.12

# %% [markdown]
# **Objetos**
#
# Em Python, Tudo é Objeto!

# %%
# Criando uma lista
lst_num = ["Data", "Science", "Academy", "Nota", 10, 10]

# %%
# A lista lst_num é um objeto, uma instância da classe lista em Python
type(lst_num)
# Out:
# list

# %%
print(type([]))
# Out:
# <class 'list'>

# %%
lst_num.count(10)
# Out:
# 2

# %%
# Usamos a função type, para verfificar o tipo de um objeto
print(type(10))
print(type([]))
print(type(()))
print(type({}))
print(type('a'))
# Out:
# <class 'int'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'str'>

# %%
# Criando um novo tipo de objeto chamado Carro
class Carro(object):
    pass # Não faz nada

# %%
# Instância do Carro
ferrari = Carro()

# %%
print(type(ferrari))
# Out:
# <class '__main__.Carro'>

# %%
# Criando uma classe
class Estudante:
    def __init__(self, nome, idade, nota):
        self.nome = nome
        self.idade = idade
        self.nota = nota

# %%
# Criando um objeto chamado Estudante1 a partir da classe Estudante
Estudante1 = Estudante("Bob", 12, 9.5)

# %%
# Atributo da classe Estudante, utilizado por cada objeto criado a partir desta classe
Estudante1.nome
# Out:
# 'Bob'

# %%
# Atributo da classe Estudante, utilizado por cada objeto criado a partir desta classe
Estudante1.idade
# Out:
# 12

# %%
# Atributo da classe Estudante, utilizado por cada objeto criado a partir desta classe
Estudante1.nota
# Out:
# 9.5

# %%
# Criando uma classe
class Funcionario:

    def __init__(self, nome, salario, cargo):
        self.nome = nome
        self.salario = salario
        self.cargo = cargo

    def listfunc(self):
        # Concatenação de strings
        print(f"Funcionário(a) " + self.nome + " tem salário de R$" + str(self.salario) + " e o cargo é " + self.cargo)

# %%
# Criando um objeto chamado Func1 a partir da classe Funcionarios
Func1 = Funcionario("Mary", 20000, "Cientista de Dados")

# %%
# Usando o método da classe
Func1.listfunc()
# Out:
# Funcionário(a) Mary tem salário de R$20000 e o cargo é Cientista de Dados

# %%
print("**** Usando atributos ****")
# Out:
# **** Usando atributos ****

# %%
hasattr(Func1, "nome") # hasattr verifica se o objeto Func1 tem o atributo nome
# Out:
# True

# %%
hasattr(Func1, "salario")
# Out:
# True

# %%
setattr(Func1, "salario", 4500) # setattr é um método que permite alterar o valor de um atributo de um objeto

# %%
hasattr(Func1, "salario")
# Out:
# True

# %%
getattr(Func1, "salario") # getattr é uma função que retorna o valor de um atributo de um objeto
# Out:
# 4500

# %%
delattr(Func1, "salario") # delattr é uma função que deleta um atributo de um objeto

# %%
hasattr(Func1, "salario")
# Out:
# False
