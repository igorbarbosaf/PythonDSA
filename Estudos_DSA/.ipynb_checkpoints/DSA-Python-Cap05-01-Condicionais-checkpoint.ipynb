# %%
sds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10828\364109357.py in <module>
# ----> 1 sds
#
# NameError: name 'sds' is not defined

# %%
asd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10828\3279299088.py in <module>
# ----> 1 asd
#
# NameError: name 'asd' is not defined
