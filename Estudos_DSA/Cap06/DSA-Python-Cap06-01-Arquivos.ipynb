# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %% [markdown]
# **Manipulação de Arquivos**
#
# Lendo Arquivos

# %%
# Abrindo o arquivo para leitura
arq1 = open("arquivos/arquivo1.txt", "r") # r = read

# %%
type(arq1)
# Out:
# _io.TextIOWrapper

# %%
# Lendo o arquivo
print(arq1.read())
# Out:
# A Data Science Academy fornece cursos de alta qualidade e que transmitem muito conhecimento.

# %%
# Contar o número de caracteres
print(arq1.tell())
# Out:
# 92

# %%
# Lendo o arquivo
print(arq1.read())

# %%
# Retornar para o início do arquivo
print(arq1.seek(0,0))
# Out:
# 0

# %%
# Lendo os primeiros 23 caracteres
print(arq1.read(23))
# Out:
# A Data Science Academy

# %% [markdown]
# **Gravando Arquivos**

# %%
# Abrindo arquivo para gravação
arq2 = open("arquivos/arquivo2.txt", "w") # W = write

# %%
# Como abrimos o arquivo apenas para gravação, não podemos usar comandos de leitura.
print(arq2.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9360\935622139.py in <module>
#       1 # Como abrimos o arquivo apenas para gravação, não podemos usar comandos de leitura.
# ----> 2 print(arq2.read())
#
# UnsupportedOperation: not readable

# %%
# Gravando arquivo
arq2.write("Aprendendo a programar em Python.")
# Out:
# 33

# %%
arq2.close()

# %%
# Lendo arquivo gravado
arq2 =open("arquivos/arquivo2.txt", "r")

# %%
print(arq2.read())
# Out:
# Aprendendo a programar em Python.

# %%
# Acrescentando conteúdo
arq2 = open("arquivos/arquivo2.txt", "a") # a = append

# %%
arq2.write(" E a metodologia de ensino da Data Science Academy facilita o aprendizado.")
# Out:
# 74

# %%
arq2.close()

# %%
arq2 = open("arquivos/arquivo2.txt", "r")

# %%
print(arq2.read())
# Out:
# Aprendendo a programar em Python.E a metodologia de ensino da Data Science Academy facilita o aprendizado. E a metodologia de ensino da Data Science Academy facilita o aprendizado. E a metodologia de ensino da Data Science Academy facilita o aprendizado. E a metodologia de ensino da Data Science Academy facilita o aprendizado.

# %%
print(arq2.seek(0,0))
# Out:
# 0

# %%
print(arq2.read())
# Out:
# Aprendendo a programar em Python.E a metodologia de ensino da Data Science Academy facilita o aprendizado. E a metodologia de ensino da Data Science Academy facilita o aprendizado. E a metodologia de ensino da Data Science Academy facilita o aprendizado. E a metodologia de ensino da Data Science Academy facilita o aprendizado.

# %% [markdown]
# **Abrindo Dataset em Linha Única**
