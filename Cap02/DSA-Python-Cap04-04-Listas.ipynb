# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %% [markdown]
# **Trabalhando com listas**

# %%
# Criando uma lista
lista_1 = ["arroz, frango, tomate, leite"]

# %%
type(lista_1)
# Out:
# list

# %%
# Imprimindo a lista
print(lista_1)
# Out:
# ['arroz, frango, tomate, leite']

# %%
# Criando outra lista
lista_2 = ["arroz", "frango", "tomate", "leite"]

# %%
type(lista_2)
# Out:
# list

# %%
# Imprimindo a lista
print(lista_2)
# Out:
# ['arroz', 'frango', 'tomate', 'leite']

# %%
# Criando lista
lista_3 = [23, 100, "Cientista de Dados"]

# %%
type(lista_3)
# Out:
# list

# %%
# Imprimindo a lista
print(lista_3)
# Out:
# [23, 100, 'Cientista de Dados']

# %%
# Atribuindo cada valor da lista a uma variável.
item1 = lista_3[0]
item2 = lista_3[1]
item3 = lista_3[2]

# %%
# imprimindo as variáveis
print(item1, item2, item3)
# Out:
# 23 100 Cientista de Dados

# %% [markdown]
# **Atualizando Um item da Lista**

# %%
lista_2
# Out:
# ['arroz', 'frango', 'tomate', 'leite']

# %%
# imprimindo um item da lista
lista_2[2]
# Out:
# 'tomate'

# %%
# Atualizando um item da lsita
lista_2[2] = "chocolate"

# %%
# Imprimindo lista alterada
lista_2
# Out:
# ['arroz', 'frango', 'chocolate', 'leite']

# %% [markdown]
# **Deletando Um Item da Lista**

# %%
lista_2
# Out:
# ['arroz', 'frango', 'chocolate', 'leite']

# %%
# Não é possivel deletar um item que não existe na lista. Vai gerar erro index out of range
del lista_2[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10852\963727625.py in <module>
#       1 # Não é possivel deletar um item que não existe na lista. Vai gerar erro index out of range
# ----> 2 del lista_2[4]
#
# IndexError: list assignment index out of range

# %%
# Deletando um item específico da lista
del lista_2[3]

# %%
# Imprimindo o item com a lista alterada
lista_2
# Out:
# ['arroz', 'frango', 'chocolate']
